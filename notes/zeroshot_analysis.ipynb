# %%
import pickle

with open('../data/processed/zeroshot.pkl', 'rb') as f :
    output = pickle.load(f)
    output = list(map(lambda x : x[0]['generated_text'], output))

# %%
print(output[12])
# Out:
# {
#     "context": "HTN, CAD, GERD, DM, OA, BPH",
#     "main_concerns": [
#         "HTN",
#         "CAD s/p MI",
#         "Gout",
#         "Depression",
#         "BPH",
#         "DM",
#         "OA",
#         "HPL",
#         "BPH s/p BC",
#         "GERD",
#         "HPL",
#         "BPH s/p BC",
#         "CPAP"
#     ],
#     "followup_date": "2021-06-26",
#     "next_appt": "2021-05-28",
#     "instructions": [
#         "follow-up in 3 months",
#         "check CXR, the pt will need a bronchoscopy, he has an appt with Dr name, name set him up for something sooner.",
#         "Continue current inhalers and O2 therapy",
#         "doing well per cards Dr name",
#         "Continue current meds",
#         "check HbA1c, UA",
#         "Established with xxxx and Podiatry",
#         "Check CMP, UA",
#         "check HbA1c, UA",
#         "will monitor for now",
#         "Seeing Dr name",
#         "Resolved s/p BCG",
#         "Follow up: 3 months"
#     ]
# }
