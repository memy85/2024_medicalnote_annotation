# %%
import pandas as pd

extractedJargons = pd.read_pickle("../data/processed/discharge_extracted_jargons.pkl")

# %%
print(extractedJargons['text'][0])
# Out:
#
# Name:  ___                    Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: MEDICINE
#
# Allergies:
# Anticholinergics,Other / Reglan
#
# Attending: ___.
#
# Chief Complaint:
# Abdominal pain
#
# Major Surgical or Invasive Procedure:
# None
#
#
# History of Present Illness:
# Patient is a ___ yo woman with history of chronic pancreatitis
# s/p cholecystectomy and sphincterotomy who presents with 1wk of
# worsening abdominal pain. As per patient, the pain is
# intermittent, sharp and ___ in quality. It localizes to her
# mid/righ upper abdomen and radiates up the chest wall and to the
# back. Patient finds this pain to be very similar to her prior
# pancreatitis flare-ups. Denies precipitants including alcohol
# use, abd. trauma, infections or h/o gallstones. She notes that
# she is on a restricted diet (no caffeine/fatty food/fried
# food/dairy) as part of her pancreatitis management. Also notes
# ...

# %%
terms = extractedJargons['extracted_jargons'][0]
len(terms)
# Out:
# 185

# %%
terms
# Out:
# {'abd',
#  'abdomen',
#  'abdominal',
#  'acetaminophen',
#  'acute on chronic',
#  'admission',
#  'admitted',
#  'advanced directive',
#  'afebrile',
#  'albumin',
#  'alt',
#  'amylase',
#  'anticholinergics',
#  'attach',
#  'attending',
#  'baseline',
#  'bilaterally',
#  'biliary',
#  'bland diet',
#  'blood glucose',
#  'bowel rest',
#  'bp',
#  'c / v',
#  'c1 inhibitor',
#  'caffeine',
#  'calcium',
#  'capsule',
#  'celiac',
#  'chest pain',
#  'chief complaint',
#  'cholecystectomy',
#  'chronic pancreatitis',
#  'close',
#  'collection',
#  'constricted',
#  'course',
#  'crackles',
#  'ct',
#  'cva',
#  'deficiency',
#  'delayed release',
#  'derm',
#  'diarrhea',
#  'dilatation',
#  'dilaudid',
#  'discharge',
#  'discharge condition',
#  'discharge date',
#  'discharge diagnosis',
#  'discharge instructions',
#  'discharge medications',
#  'disposition',
#  'distal',
#  'distended',
#  'dni',
#  'dnr',
#  'ed',
#  'elevated',
#  'enzymes',
#  'epigastrium',
#  'ercp',
# ...
