# %%
import pickle
import pandas as pd
import math
from utils import *

config = load_config()

# %%
# PROJECT_PATH = config.project_path
PROJECT_PATH = config.file_path
DATA_PATH = PROJECT_PATH.joinpath("data/processed")

def load_data( name ) :
    with open(DATA_PATH.joinpath(name), 'rb') as f :
        data = pickle.load(f)
    return data

# %%
def print_results(df) :
    df = df.drop(columns = ['cv', 'topN']).copy()
    df = df.groupby(['model', 'shots']).agg({'precision':lambda x : "{mean:.3f} ({hi:.3f}/{lo:.3f})".format(mean = x.mean(), hi=x.mean() + 1.96*x.std()/math.sqrt(5),lo=x.mean() - 1.96*x.std()/math.sqrt(5)),
                                        'recall': lambda x : "{mean:.3f} ({hi:.3f}/{lo:.3f})".format(mean = x.mean(), hi=x.mean() + 1.96*x.std()/math.sqrt(5),lo=x.mean() - 1.96*x.std()/math.sqrt(5)),
                                        'f1': lambda x : "{mean:.3f} ({hi:.3f}/{lo:.3f})".format(mean = x.mean(), hi=x.mean() + 1.96*x.std()/math.sqrt(5),lo=x.mean() - 1.96*x.std()/math.sqrt(5)),
                                        'mrr': lambda x : "{mean:.3f} ({hi:.3f}/{lo:.3f})".format(mean = x.mean(), hi=x.mean() + 1.96*x.std()/math.sqrt(5),lo=x.mean() - 1.96*x.std()/math.sqrt(5)),
                                        })
    return df.sort_values(by='shots', ascending=False)

# %%
# top3 

mistral7b_finetuned_zeroshot = load_data("top3_mistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
mistral7b_finetuned_fewshot = load_data("top3_mistral7b_mimic_finetuned_fewshot_evaluation.pkl")
# biomistral7b_finetuned_zeroshot = load_data("top3_biomistral7b_zeroshot_evaluation.pkl")
# biomistral7b_finetuned_fewshot = load_data("top3_biomistral7b_fewshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_zeroshot = load_data("top3_biomistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_fewshot = load_data("top3_biomistral7b_mimic_finetuned_fewshot_evaluation.pkl")

evaluation_results = [ mistral7b_finetuned_zeroshot, mistral7b_finetuned_fewshot,]
                    #   biomistral7b_finetuned_zeroshot, biomistral7b_finetuned_fewshot,]
                      # biomistral7b_avigon_finetuned_zeroshot, biomistral7b_avigon_finetuned_fewshot]
results = []
for evaluation in evaluation_results :
    for record in evaluation :
        results.append(record)

myResults = pd.DataFrame(results)

# %%
print_results(myResults)

# %%
# top5

mistral7b_finetuned_zeroshot = load_data("top5_mistral7b_modified_zeroshot_evaluation.pkl")
mistral7b_finetuned_fewshot = load_data("top5_mistral7b_modified_fewshot_evaluation.pkl")
biomistral7b_finetuned_zeroshot = load_data("top5_biomistral7b_avigon_modified_zeroshot_evaluation.pkl")
biomistral7b_finetuned_fewshot = load_data("top5_biomistral7b_avigon_modified_fewshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_zeroshot = load_data("top5_biomistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_fewshot = load_data("top5_biomistral7b_mimic_finetuned_fewshot_evaluation.pkl")

evaluation_results = [mistral7b_finetuned_zeroshot, mistral7b_finetuned_fewshot,
                      biomistral7b_finetuned_zeroshot, biomistral7b_finetuned_fewshot,]
                      # biomistral7b_avigon_finetuned_zeroshot, biomistral7b_avigon_finetuned_fewshot]

results = []
for evaluation in evaluation_results :
    for record in evaluation :
        results.append(record)

myResults = pd.DataFrame(results)

# %%
print_results(myResults)
# Out:
#                                                  precision  \
# model               shots
# biomistral7b_avigon modified_zeroshot  0.536 (0.576/0.496)
# mistral7b           modified_zeroshot  0.376 (0.394/0.358)
# biomistral7b_avigon modified_fewshot   0.683 (0.702/0.664)
# mistral7b           modified_fewshot   0.433 (0.443/0.423)
#
#                                                     recall  \
# model               shots
# biomistral7b_avigon modified_zeroshot  0.132 (0.146/0.119)
# mistral7b           modified_zeroshot  0.305 (0.320/0.291)
# biomistral7b_avigon modified_fewshot   0.136 (0.139/0.134)
# mistral7b           modified_fewshot   0.291 (0.298/0.283)
#
#                                                         f1  \
# model               shots
# biomistral7b_avigon modified_zeroshot  0.212 (0.233/0.192)
# mistral7b           modified_zeroshot  0.337 (0.352/0.321)
# biomistral7b_avigon modified_fewshot   0.227 (0.232/0.223)
# mistral7b           modified_fewshot   0.348 (0.355/0.340)
#
#                                                        mrr
# model               shots
# biomistral7b_avigon modified_zeroshot  0.433 (0.469/0.397)
# mistral7b           modified_zeroshot  0.563 (0.590/0.535)
# biomistral7b_avigon modified_fewshot   0.510 (0.537/0.482)
# mistral7b           modified_fewshot   0.579 (0.605/0.553)

# %%
# top10

# mistral7b_finetuned_zeroshot = load_data("top10_mistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
# mistral7b_finetuned_fewshot = load_data("top10_mistral7b_mimic_finetuned_fewshot_evaluation.pkl")
# biomistral7b_finetuned_zeroshot = load_data("top10_biomistral7b_avigon_zeroshot_evaluation.pkl")
# biomistral7b_finetuned_fewshot = load_data("top10_biomistral7b_avigon_fewshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_zeroshot = load_data("top10_biomistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_fewshot = load_data("top10_biomistral7b_mimic_finetuned_fewshot_evaluation.pkl")

# evaluation_results = [ # mistral7b_finetuned_zeroshot, mistral7b_finetuned_fewshot]
                      # biomistral7b_finetuned_zeroshot, biomistral7b_finetuned_fewshot]
                    #   biomistral7b_avigon_finetuned_zeroshot, biomistral7b_avigon_finetuned_fewshot]

mistral7b_finetuned_zeroshot = load_data("top5_mistral7b_modified_zeroshot_evaluation.pkl")
mistral7b_finetuned_fewshot = load_data("top5_mistral7b_modified_fewshot_evaluation.pkl")
biomistral7b_finetuned_zeroshot = load_data("top5_biomistral7b_avigon_modified_zeroshot_evaluation.pkl")
biomistral7b_finetuned_fewshot = load_data("top5_biomistral7b_avigon_modified_fewshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_zeroshot = load_data("top5_biomistral7b_mimic_finetuned_zeroshot_evaluation.pkl")
# biomistral7b_avigon_finetuned_fewshot = load_data("top5_biomistral7b_mimic_finetuned_fewshot_evaluation.pkl")

evaluation_results = [mistral7b_finetuned_zeroshot, mistral7b_finetuned_fewshot,
                      biomistral7b_finetuned_zeroshot, biomistral7b_finetuned_fewshot,]
                      # biomistral7b_avigon_finetuned_zeroshot, biomistral7b_avigon_finetuned_fewshot]
results = []
for evaluation in evaluation_results :
    for record in evaluation :
        results.append(record)

myResults = pd.DataFrame(results)

# %%
t = print_results(myResults)
t
# Out:
#                                                  precision
# model                        shots
# biomistral7b_mimic_finetuned zeroshot  0.322 (0.341/0.303)  \
#                              fewshot   0.249 (0.262/0.235)
#
#                                                     recall
# model                        shots
# biomistral7b_mimic_finetuned zeroshot  0.322 (0.342/0.301)  \
#                              fewshot   0.244 (0.259/0.230)
#
#                                                         f1
# model                        shots
# biomistral7b_mimic_finetuned zeroshot  0.322 (0.341/0.303)  \
#                              fewshot   0.246 (0.260/0.233)
#
#                                                        mrr
# model                        shots
# biomistral7b_mimic_finetuned zeroshot  0.469 (0.513/0.426)
#                              fewshot   0.445 (0.469/0.421)

# %% [markdown]
# These are just left for insurance. I may need them someday

# %%
import math
stats = myResults.groupby(['model','shots'])[['precision', 'recall', 'f1', 'mrr']].agg(['mean', 'count', 'std'])

for score in ['precision','recall', 'f1', 'mrr'] : 
    ci95_hi = []
    ci95_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i][score]
        ci95_hi.append(m + 1.96*s/math.sqrt(c))
        ci95_lo.append(m - 1.96*s/math.sqrt(c))

    # stats[score]['ci95_hi'] = ci95_hi
    # stats[score]['ci95_lo'] = ci95_lo
    stats.loc[:,(score,'ci95_hi')] = ci95_hi
    stats.loc[:,(score,'ci95_lo')] = ci95_lo

# %%
# precision
stats['precision']
# Out:
#                                       mean  count       std   ci95_hi
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.1376      5  0.002074  0.139418  \
#                           zeroshot  0.1440      5  0.005568  0.148880
#
#                                      ci95_lo
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.135782
#                           zeroshot  0.139120

# %%
# recall
stats['recall']
# Out:
#                                       mean  count       std   ci95_hi
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.1426      5  0.006693  0.148467  \
#                           zeroshot  0.1424      5  0.004775  0.146585
#
#                                      ci95_lo
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.136733
#                           zeroshot  0.138215

# %%
# f1
stats['f1']
# Out:
#                                       mean  count       std   ci95_hi
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.1398      5  0.004087  0.143382  \
#                           zeroshot  0.1432      5  0.004712  0.147330
#
#                                      ci95_lo
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.136218
#                           zeroshot  0.139070

# %%
# mrr
stats['mrr']
# Out:
#                                       mean  count       std   ci95_hi
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.1822      5  0.017754  0.197762  \
#                           zeroshot  0.0918      5  0.011692  0.102048
#
#                                      ci95_lo
# model                     shots
# mistral7b_mimic_finetuned fewshot   0.166638
#                           zeroshot  0.081552
