# %% [markdown]
# ## This notebook is to load the annotated dataset and work with it.

# %% [markdown]
# Input: a EHR note (MIMIC)
#
# Instruction: Please identify 5~10 word tokens from the EHR note. Those 5~10 word tokens should be most important for a patient to understand their clinical conditions, procedures, and treatment plans.
#
# Output: keywords [use either human annotated, or just use MIMIC outputs
# [overlapping keywords between notes and discharge instructions- advantage: llama and GPT4]

# %% [markdown]
# ## ======================================= Process annotation notes

# %% [markdown]
# ## ========================================== Process with Rankings

# %%
import pandas as pd
import random

pages = ['victoria', 'jiaping', 'jinying-3A', 'jinying-2B-part1', 'jinying_2B_part2','jinying_3C']

datas = []
for page in pages :
    # df = pd.read_excel("../data/raw/all_20160531.xlsx", page)
    df = pd.read_excel("../data/processed/all_20160531_changed.xlsx", page)
    datas.append(df)

# %%
def preprocess_data(data, topn, ids = []) :
    data = data.dropna(subset=['ranking']).copy()
    # data = data.drop(columns = ['packet'])

    data['fileid'] = data['fileid'].str.lower()
    data['fileid'] = data['fileid'].str.strip()
    data['fileid'] = data.fileid.str.replace('heart failure', 'heart_failure')
    data['fileid'] = data.fileid.str.replace('liver failure', 'liver_failure')
    data['fileid'] = data['fileid'].str.replace(" ", "")
    data['fileid'] = data['fileid'].apply(lambda x : x + '.txt' if not x.endswith('.txt') else x)

    # process phrases
    data['phrase'] = data['phrase'].str.lower()
    data['phrase'] = data['phrase'].str.strip()

    # process colors 
    data['color'] = data['color'].str.lower()
    data['color'] = data['color'].replace({"yellow" : "y", "green" : "g"})

    data = data.dropna()

    # symptoms
    symptoms = data[data.color == 'y'].sort_values(by=['fileid', 'ranking']).groupby(['fileid','color']).head(topn)
    symptoms = symptoms.drop_duplicates(subset=['fileid', 'phrase'])

    # tests
    labtests = data[data.color == 'g'].sort_values(by=['fileid', 'ranking'])
    labtests = labtests[labtests.ranking < (topn + 1)].copy()

    result = pd.concat([symptoms, labtests], ignore_index=True)
    result = result.sort_values(by=['fileid','ranking'])

    # grouped = data.sort_values(by=['fileid','ranking'])
    # result = grouped.groupby(['fileid']).head(topn)

    result = result.drop_duplicates(subset=['fileid', 'ranking'])
    result = result[~result.fileid.isin(ids)].reset_index(drop=True)
    return result.reset_index(drop=True), result['fileid'].unique().tolist()

# %%
# don't erase this!
# These are the examples that we will use

example_text = "cancer.report24.txt"
example_texts = ["cancer.report24.txt", "diabetes.report310966.txt"]

# %%
processed_datasets_top3 = []
ids = []

# leave 20 samples for finetuning
random.seed(52)
sample_size = 20


for data in datas :
    processed, data_ids = preprocess_data(data, 3, ids)
    processed_datasets_top3.append(processed)
    ids.extend(data_ids)


sample_ids = random.sample(ids, sample_size)
top3_dataset = pd.concat(processed_datasets_top3, ignore_index=True)
top3_dataset = top3_dataset[~(top3_dataset.fileid.isin(example_texts) | (top3_dataset.fileid.isin(sample_ids)))].reset_index(drop=True)
# top3_samples = top3_dataset[top3_dataset.fileid.isin(sample_ids)]


processed_datasets_top5 = []
ids = []
for data in datas :
    processed, data_ids = preprocess_data(data, 5, ids)
    processed_datasets_top5.append(processed)
    ids.extend(data_ids)


top5_dataset = pd.concat(processed_datasets_top5, ignore_index=True)
top5_dataset = top5_dataset[~(top5_dataset.fileid.isin(example_texts) | (top5_dataset.fileid.isin(sample_ids)))].reset_index(drop=True)
# top5_samples = top5_dataset[top5_dataset.fileid.isin(sample_ids)]

processed_datasets_top10 = []
ids = []
for data in datas :
    processed, data_ids = preprocess_data(data, 10, ids)
    processed_datasets_top10.append(processed)
    ids.extend(data_ids)

top10_dataset = pd.concat(processed_datasets_top10, ignore_index=True)
top10_dataset = top10_dataset[~(top10_dataset.fileid.isin(example_texts) | (top10_dataset.fileid.isin(sample_ids)))].reset_index(drop=True)
# top10_samples = top10_dataset[top10_dataset.fileid.isin(sample_ids)]

processed_datasets_top20 = []
ids = []
for data in datas :
    processed, data_ids = preprocess_data(data, 20, ids)
    processed_datasets_top20.append(processed)
    ids.extend(data_ids)

# %%
sample_df = pd.concat(processed_datasets_top20)
sample_df = sample_df[sample_df.fileid.isin(sample_ids)].copy()

# %% [markdown]
# Now merge with notes

# %%
import pandas as pd

notes = pd.read_pickle("../data/processed/notes.pkl")
notes
# Out:
#           category                         noteid
# 0    liver_failure  liver_failure.report37286.txt  \
# 1    liver_failure  liver_failure.report37775.txt
# 2    liver_failure  liver_failure.report38874.txt
# 3    liver_failure  liver_failure.report41972.txt
# 4    liver_failure  liver_failure.report51432.txt
# ..             ...                            ...
# 281  heart_failure  heart_failure.report80980.txt
# 282  heart_failure  heart_failure.report85881.txt
# 283  heart_failure   heart_failure.report9402.txt
# 284  heart_failure  heart_failure.report94858.txt
# 285  heart_failure  heart_failure.report97080.txt
#
#                                                   text
# 0    This is a 50-year-old male with a history of d...
# 1    Dr. name has discussed these results with you....
# 2    F/u on Osteoarthritis, chronic pain, HTN, Depr...
# 3    Very high a1c and glucose please follow up in ...
# 4    name is a lovely just turned 65-year-old gentl...
# ..                                                 ...
# 281  1. Multifactorial anemia secondary to both ren...
# 282  The patient is being seen for an initial evalu...
# 283  This 86-year-old coming in for a complete chec...
# 284  The patient presents today for evaluation for ...
# 285  Mr. name name is a 79-year-old right handed wh...
#
# [286 rows x 3 columns]

# %%
print(notes[notes.noteid == 'diabetes.report310966.txt']['text'][205])
# Out:
# name name is a 58-year-old man referred for evaluation of thrombocytosis. Prior CBCs from xxxx through xxxx revealed platelet counts ranging from 400,000 to 500,000, but no more recent studies are available. He has long-standing Crohn disease and although he says he has not had gastrointestinal bleeding in the past, he has been given iron, which he is taking twice daily. He has black stool, but notes no blood and he has not had hematemesis. He notes no blood in his urine or sputum and he has no epistaxis. He discontinued the use of iron yesterday because he thought that might alleviate his gastrointestinal complaints, but he does not feel different today. He is cared for by Dr. name name at St. hospital Medical Center in location. He has no history of prior cancers, tuberculosis or other infectious diseases. He has been taking budesonide for his Crohn disease. He has no unexplained fevers, although he states he often feels hot. He has no soaking sweats and has not had unexplained weight loss. He believes he was referred to an oncologist many years ago at Streetin location, xxxx, but he cannot recall the reason for that referral, who the doctor was, or what the findings were. He often feels queasy and nauseated, but has no vomiting. He has loose stools up to 4 days per week, but has had a stable pattern of Crohn disease. Also notable for diabetes mellitus for which he takes metformin and has required no insulin and has had no complications of retinopathy or renal dysfunction, Crohn disease as described above and an enlarged prostate.
# Aspirin, budesonide 3 mg extended release tablet b.i.d., docusate sodium, fenofibrate, ibuprofen, metformin 500 mg 4 times a day, omeprazole and vitamin D.
# He has no known drug allergies.
# He is a former construction worker and carpenter on disability since xxxx. He is active doing yard work. He has no formal exercise regimen. He eats a well-balanced diet and recently experimented with a gluten-free diet. He smokes occasional cannabis. Drinks no alcohol, although he drank at least a 12-pack of beer daily and often more until 3 years ago. He had no history of withdrawal symptoms, seizures or delirium tremens and did not know of cirrhosis or liver disease. He does not smoke cigarettes.
# Father died at age 80 with an unknown cancer that may have been prostate cancer. His mother died at age 68 with an unknown blood disorder. He has an older brother with diabetes, 2 older sisters and a younger sister, all of whom are well. He has a son who is 28 and a daughter who is 24, both of whom are competitive athletes and healthy. No clear family history of hematologic malignancies, although his mother died with an unknown blood disorder.
# Notable for the absence of abdominal fullness, early satiety, nausea or vomiting. He has black stools, but no bloody stools. Weight has been stable. No fevers or soaking sweats. All other systems are negative except as detailed in the HPI.
#
# Blood pressure 123/75, pulse 83, respirations 18, temperature 36.9, weight 75.1 kg, height 166.9 cm and pulse oximetry 98% on room air.
# This is a well-developed, well-nourished man with numerous somatic complaints, but appropriate affect, alert and oriented x3, and moving comfortably about the room in no distress.
# Warm and dry with no evidence of bleeding or bruising.
# His sclerae are anicteric. Tongue is well papillated. No cheilosis. Extraocular muscles are intact. Pupils equal, round and reactive to light. Slightly muddy sclerae.
# No cervical or supraclavicular lymphadenopathy.
# Clear to auscultation.
# No tenderness of the spine or CV angles.
# Heart sounds are regular. Normal S1 and S2. No murmur, rub or gallop is heard.
# Muscular, soft, nontender. Bowel sounds normoactive. No palpable organomegaly or masses. I cannot palpate the spleen even in the right lateral decubitus position.
# No peripheral cyanosis, clubbing or edema. Normal motor function in all 4 extremities, normal light touch.
# Cranial nerves II through XII are intact.
# name name is a 58-year-old man referred for evaluation of thrombocytosis. No recent laboratory studies are available to me and labs from xxxx are pending at this time. He has had long-standing mild thrombocytosis and the potential differential diagnosis is large; notable contributors may be his Crohn disease of several years' duration, possible gastrointestinal bleeding with iron deficiency anemia. There is no clinical evidence of chronic infections in the form of tuberculosis or fungal infections and he has no clear autoimmune illness. He does not manifest symptoms of name from iron deficiency, but I did ask him to continue to take oral iron until we have iron studies available. The differential diagnosis also includes myeloproliferative neoplasms, and I await the results of the CBC before ordering more specialized tests, such as BCR-ABL for CML. I have asked him to return to see me in 1-2 weeks after laboratory studies are available. He promised to obtain results from name name and other specialists whom he has seen.
# ||||END_OF_RECORD

# %%
notes['noteid'].nunique()
# Out:
# 286

# %%
import pickle

# the data are 105 dataset
file_top3 = top3_dataset['fileid'].unique()
# file_top5 = top3_dataset['fileid'].unique()

filtered_notes = notes[notes.noteid.isin(file_top3)].reset_index(drop=True)

sample_notes = notes[notes.noteid.isin(sample_ids)].reset_index(drop=True)

processed_ranking_datasets = (top3_dataset, top5_dataset, top10_dataset, filtered_notes, sample_df, sample_notes)

with open("../data/processed/processed_ranking_datasets.pkl", 'wb') as f :
    pickle.dump(processed_ranking_datasets, f)

# %%
print(notes[~notes.noteid.isin(example_texts)]['text'].values[0])
# Out:
# This is a 50-year-old male with a history of diarrhea-predominant irritable bowel syndrome, who is coming in complaining of a one-month history of abdominal cramping in the epigastric region. The patient reports that his IBS was diagnosed two to three years ago when he presented with a history of alternating constipation and diarrhea post stressful events. He reports that his usual IBS flares last for 24-48 hours after a clear stressor and then spontaneously resolve. He reports that he had a sigmoidoscopy at that time, which was unremarkable, to rule out other pathologies such as IBD. He also has in the intervening time had a screening colonoscopy, where he underwent a polypectomy about two to three years ago, during which time he was also again found to not have any lesions consistent with inflammatory bowel disease. The patient reports that his IBS has been well controlled. About a month ago, he purchased a plane with the intent of renewing his pilot's license and has been stressed from this purchase as well as repeating his flight school. He reports that during this time, he has had a month of epigastric and right upper quadrant crampy abdominal pain, about xxx at baseline and only going up to an intensity of 2/10. These reports it as a crampy sensation associated with flatulence and belching. He reports that passage of gas actually relieves the pain. He also reports that passage of bowel movements also relieves the pain. He states that he has had no changes in his bowel patterns. He has two well-formed appropriately-colored bowel movements on a daily basis. He had been taking Colace until a week prior because he had a flareup of his hemorrhoids; however, this has resolved over the last week, and he reports no further bowel movement abnormalities. He has also no urinary abnormalities. He denies dysuria. He has no problems initiating urinary stream. He has no hesitancy and has no sensation of postvoid residual. Otherwise, he denies fevers, chills, headaches, chest pain, palpitation, shortness of breath, lower extremity swelling, mouth lesions, joint pain, any new rashes, or hair loss. He does have a 20- to 25-pound weight loss over the last year, which is intentional with dietary restriction being the primary method of weight loss.PAST MEDICAL HISTORY
# 1. History of migraines, now well controlled.
# 2. History of irritable bowel syndrome with alternating constipation and diarrhea, although usually diarrhea-predominant.
# 3. History of urinary frequency, now resolved.
# 4. Seasonal allergies with postnasal drip and cough.
# 5. History of stable pituitary microadenoma, not requiring any intervention.
# 6. History of steatohepatitis.
# 7. History of hypertriglyceridemia.
# 8. History of vestibular neuritis.
# 9. History of hypertension.
# MEDICATIONS
# 1. Claritin.
# 2. Lisinopril 20 mg orally daily.
# 3. Prilosec 20 mg orally daily.
# His maternal uncle had a colorectal cancer in his 60s. His paternal cousin has cystic fibrosis. He reports that he has been screened for cystic fibrosis and was found to be negative. His father has diabetes mellitus.
# The patient is currently undergoing flight school. He has previously worked as an airline mechanic. He is an everyday smoker, smokes about five cigarettes per day for multiple years, and is uninterested in smoking cessation. He does not drink alcohol. He has no IV drug use, marijuana, or cocaine use. He is divorced and has a teenage son.
# A 12-point review of systems is negative, except as above.
# Vital signs: BMI 32.14 kg/m2, blood pressure 126/94, heart rate 92, temperature 98.4. Pain level is 1 in the epigastric region. HEENT: Mucous membranes are moist. Extraocular muscles are intact. Pupils are equally round and reactive to light bilaterally. Tympanic membranes were intact, although only partially visualized due to bilateral cerumen impaction. No oral lesions were noted. Neck: No jugular venous distention, no anterior cervical lymphadenopathy, no palpable thyroid masses. Cardiac: Regular rate and rhythm, S1 and S2 normal. No murmurs, rubs, or gallops were appreciated. Lungs: Clear to auscultation bilaterally. No rales, rhonchi, or wheezing were appreciated. Abdomen: Overweight, nontender to superficial and deep palpation. No visible herniation. No palpable organomegaly. I could not reproduce any pain with any of the physical examination. He did have tympanitic abdomen with good bowel sounds in all four quadrants. Rectal examination was performed, which showed some nonbleeding external hemorrhoids. No fissures were noted. Extremities: No cyanosis. No edema. Peripheral pulses were 2+. Skin: No rashes or lesions were noted. Musculoskeletal: No obvious visible joint deformities.
# This is a 50-year-old overweight gentleman with a past medical history of diarrhea-predominant irritable bowel syndrome who is coming in with a one-month history of abdominal cramping associated with a sensation of abdominal distention, relieved by passage of gas. The patient's presentation is consistent with possible irritable bowel syndrome flareup, especially given no constitutional symptoms, other than intentional weight loss, as well as no relation to dietary intake and changes in bowel patterns. However, we will be checking CBC, BMP, and LFTs to rule out infectious, metabolic, as well as other possible causes for his presentation. He has been prescribed simethicone for pain relief and was encouraged to continue taking the proton pump inhibitor for acid suppression, given his history of gastroesophageal reflux disease. He was counseled that if his labs were to come back as positive and/or if he had persistent symptoms despite the empiric simethicone trial, to come back to the clinic for further evaluation.
# The case was discussed with the attending, Dr. name.
# I discussed the history, exam, and plan with resident Dr. name and agree with the note above. - Dr. name
# ||||END_OF_RECORD

# %%
text = notes[notes.noteid == 'liver_failure.report38874.txt'].values[0][2]
print(text[:100])
# Out:
# F/u on Osteoarthritis, chronic pain, HTN, Depression
#
# The pt has generalized OA, in his shoulders,

# %%
sample_df[(sample_df.fileid == 'cancer.report24.txt') & (sample_df.ranking < 4)]
# Out:
#   packet               fileid                           phrase color  ranking
# 0     1B  cancer.report24.txt             rheumatoid arthritis     y      1.0
# 1     1B  cancer.report24.txt                     methotrexate     g      1.1
# 2     1B  cancer.report24.txt                        synovitis     g      1.2
# 3     1B  cancer.report24.txt                     osteoporosis     y      2.0
# 4     1B  cancer.report24.txt       anormal bone density study     g      2.1
# 5     1B  cancer.report24.txt                  biophosphonates     g      2.2
# 6     1B  cancer.report24.txt                           niacin     g      3.1
# 7     1B  cancer.report24.txt  statins wichich caused myalgias     g      3.2

# %%
def format_prompt(fileid, topN) :
    # get the EHR note
    ehr_note = notes[notes.noteid == fileid]
    input_text = ehr_note.values[0][2]

    # format the outputs 
    df = sample_df[(sample_df.fileid == fileid) & (sample_df.ranking < (topN+1))].copy()
    output_text = ""

    for idx, row in df.iterrows() :
       output_text += str(row.ranking) + " " + row.phrase + "\n" 
    
    instruction = f""" 
    You are a helpful assistant, an expert in medical domain. 
    Extract top {topN} main diagnosis/symptoms or conditions mentioned in the medical note. 
    Following the diagnosis/symptoms or conditions, identify the medical tests related to it.
    If there isn't any medical tests related to it, just start listing the next important diagnosis/symptoms or conditions.
    If there are no additional diagnosis/symptoms or conditions that you can identify, just list the existing ones and finalize the output. 
    Don't write no symptoms, or any indication that there is no other diagnosis/symptoms or conditions.
    Do not modify or abbreviate what is written in the notes. Just extract them as they are.
    Make sure the highest priority is assigned with a smaller number.
    We give you an example, do follow as below.
    The format should be as follows


    1. key symptom or condition
    1.1 medical test related to 1
    1.2 medical test related to 1

    2. key symptom or condition
    2.1 medical test related to 2

    3. key symptom or condition
    3.1 medical test related to 3
    3.2 medical test related to 3
    """

    return {"input" : input_text,
            "output" : output_text, 
            "instruction" : instruction}

# %%
parsed_dataset = []
for fileid in sample_notes['noteid'].tolist() :
    for topn in [3, 5, 10] :
        output = format_prompt(fileid, topn)
        parsed_dataset.append(output)

# %%
parsed_dataset[0]
# Out:
# {'input': "name is a lovely 53-year-old gentleman who I have not seen in a long time coming in today for followup.1. Nonischemic cardiomyopathy: The patient, in date, had a Persantine thallium for other reasons that noted an ejection fraction of 47% and there was possibly an LAD ischemia. \nHis xxx, heart catheterization showed a completely clean coronary system, but a low normal EF. \nChest x-rays did not suggest sarcoidosis and iron saturation was unremarkable. \nHis last echo was in xxx showing a normal ejection fraction. He has been maintained on beta-blockers and ACE inhibitors for blood pressure, but it is unclear if he needs as much medicine as he is on. He denies paroxysmal nocturnal dyspnea, orthopnea or pedal edema. No chest pain or palpitations. \n2. History of GERD: The patient had an EGD in date that showed no evidence of name esophagus. \nOutlet type rectal bleeding in date, colonoscopy showed just hemorrhoids. He has no abdominal pain, vomiting or nausea or bright red blood per rectum. \n3. Fatty liver: The patient has a history of elevated liver enzymes in date. Hepatitis B and C serologies were negative. Ferritin was normal. Iron saturation was borderline, but hemochromatosis gene analysis shows he has only heterozygote for H63D. A protein electrophoresis was otherwise normal and a ceruloplasmin was normal. He does not drink much alcohol. \n4. Hives: The patient does have a history of heat-induced hives. More recently, he had a flareup of hives because his daughter was hiding a rabbit in their house. \n5. Sinus polyposis status post polypectomy in xxx, breathing well out of his nose. \n6. Asthma followed by Dr. name. \n7. Aspirin allergy: The patient is maintained on aspirin suppression. \n8. Knee pain: The patient recalls twisting his knee on the left about 6 months ago while standing in a basketball court. Since then, he has been having medial joint line pain. He was seen in the emergency room. He was told he hadnt fractured anything. No x-rays were taken. The pain is enough that it bothers him to walk a lot. It does not lock or give. Now, the right knee is being bothered in the same location. \n9. Left bicipital tendon tear: The patient dropped a heavy weight on his left humerus several months ago and he notices that he has lost some strength and signature either a dent or bulge in that area. \n\n1. Doxycycline, nausea. \n2. Lisinopril, cough. \n\n1. Aspirin 325 b.i.d. \n2. Carvedilol 25 b.i.d. \n3. Cetirizine 10 a day. \n4. EpiPen if needed. \n5. Flonase nasal spray. \n6. Ipratropium nasal spray. \n7. Losartan potassium and hydrochlorothiazide 100/25 one a day. \n8. Montelukast 10 a day. \n9. Omeprazole 40 twice a day. \n10. QVAR 2 puffs twice a day. \n11. Serevent 50 mcg every 12 hours. \n12. Ventolin p.r.n. \nThe patient is a plumber Non smoker._, married, has a couple of children. Drinks a few beers a week. \nDad passed away of pneumonia in his 70s. Dad had asthma. \nMother in her mid to late 80s with high blood pressure. \nHe has 8 siblings, two of whom have scleroderma, one diet of it. \nA 12-point review of systems is otherwise negative. \n\nWeight of 264 and body mass index of 32. Blood pressure is 130/70 and pulse of 80. \nOphthalmoscopic within normal limits. Oropharynx is negative. \nNo JVD. Carotid upstrokes full, thyroid normal, no bruits. \nClear to percussion and auscultation. \nNormal S1 and S2, without rubs, gallops or murmurs. \nSoft and nontender, no organomegaly. \nWithout clubbing, cyanosis or edema. 2+ pedal pulses. Left forearm, I think he tore his bicep tendon off the ulnar and radial area. This retraction of muscle and a bulge is proximal to the antecubital fossa. Strength is okay. Reflexes are fine. Knees have no crepitance and no fluid, full range of motion. Both knees have medial joint line tenderness. No ligament laxity. Lachman's is negative. McMurray's is negative. \nDigital rectal guaiac-negative brown stool, prostate normal. \n\n1. Left forearm issues: I am getting an MRI re ...
#  'output': '1.0 nonischemic cardiomyopathy\n1.1 persantine thallium\n1.2 ejection fraction\n1.3 lad ischemia\n1.4 heart catheterization\n1.5 carvedilol\n2.0 trigger fingers\n2.1 hand clinic\n2.2 mri\n3.0 health maintenance\n3.2 prevnar vaccine\n3.3 tetanus\n3.4 a psa\n',
#  'instruction': " \n    You are a helpful assistant, an expert in medical domain. \n    Extract top 3 main diagnosis/symptoms or conditions mentioned in the medical note. \n    Following the diagnosis/symptoms or conditions, identify the medical tests related to it.\n    If there isn't any medical tests related to it, just start listing the next important diagnosis/symptoms or conditions.\n    If there are no additional diagnosis/symptoms or conditions that you can identify, just list the existing ones and finalize the output. \n    Don't write no symptoms, or any indication that there is no other diagnosis/symptoms or conditions.\n    Do not modify or abbreviate what is written in the notes. Just extract them as they are.\n    Make sure the highest priority is assigned with a smaller number.\n    We give you an example, do follow as below.\n    The format should be as follows\n\n\n    1. key symptom or condition\n    1.1 medical test related to 1\n    1.2 medical test related to 1\n\n    2. key symptom or condition\n    2.1 medical test related to 2\n\n    3. key symptom or condition\n    3.1 medical test related to 3\n    3.2 medical test related to 3\n    "}

# %%
import json
from utils import *

config = load_config()
PROJECT_PATH = config.project_path
DATA_PATH = PROJECT_PATH.joinpath("data/processed")

with open(DATA_PATH.joinpath("jinying_sample_dataset.json"), "w") as f : 
    json.dump(parsed_dataset, f)
