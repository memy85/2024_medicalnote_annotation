# %%
import pandas as pd
import random
from utils import *
random.seed(0)

config = load_config()

# %% [markdown]
# Decided to prompt using the fewshot prompt that was already developed.

# %%
# prepare 1000 examples of MIMIC notes
# use filtered discharge dataset which was used in mimicv_keyword_to_json.ipynb


PROJECT_PATH = config.project_path
DATA_PATH = PROJECT_PATH.joinpath("data/processed")

filtered_discharge_dataset = pd.read_pickle(DATA_PATH.joinpath('filtered_discharge_dataset.pkl'))

# %%
# select 1000 mimic notes
selected_mimic = filtered_discharge_dataset.sample(1000, random_state=0)
selected_mimic = selected_mimic[['note_id', 'subject_id', 'text']].reset_index(drop=True)

# %%
selected_mimic.to_pickle(DATA_PATH.joinpath("selected_mimic.pkl"))

# %% [markdown]
# ## Examples from ChatGPT

# %%
import pandas as pd
import random
from utils import *

random.seed(0)

config = load_config()

# %%
PROJECT_PATH = config.project_path
DATA_PATH = PROJECT_PATH.joinpath("data/processed")

synthetic_data = pd.read_pickle(DATA_PATH.joinpath('selected_mimic_synthetic_data.pkl'))

# %%
synthetic_data.head()
# Out:
#           note_id  subject_id
# 0  10332328-DS-27    10332328  \
# 1  10030852-DS-18    10030852
# 2  10092175-DS-10    10092175
# 3  10215754-DS-14    10215754
# 4  10089894-DS-16    10089894
#
#                                                 text
# 0   \nName:  ___                    Unit No:   __...  \
# 1   \nName:  ___                Unit No:   ___\n ...
# 2   \nName:  ___                     Unit No:   _...
# 3   \nName:  ___                   Unit No:   ___...
# 4   \nName:  ___                  Unit No:   ___\...
#
#                                           gpt_output
# 0  1. bilateral lower extremity edema\n2. chronic...
# 1  1. T1DM (Type 1 Diabetes Mellitus)\n1.1. Insul...
# 2  1. dyspnea\n2. orthopnea\n3. PND\n4. weight ga...
# 3  1. contractions\t\n2. back pain\n3. R hydronep...
# 4  1. trauma\t\n2. periprosthetic femur fracture\...

# %%
import json
import re
from utils import format_prompt


def parse_dataset_into_json(row_n, topn) :
    text = synthetic_data.iloc[row_n]['text']
    output = synthetic_data.iloc[row_n]['gpt_output']
    rank = int(topn.replace("top",""))

    p = re.compile('(\d+\.\d?)\.?\s(.+)')
    output = p.findall(output)

    numbers = list(map(lambda x : x[0], output))
    output = list(map(lambda x : x[1].strip().lower(), output))

    output = [(x,y) for x, y in zip(numbers, output)]
    output = list(filter(lambda x : int(x[0].rstrip(".")[0]) < (rank + 1), output))
    output_text = ""
    for x, y in output :
        output_text += x + " " + y + "\n"

    with open(PROJECT_PATH.joinpath(f"prompts/finetune_instruction_{topn}.txt")) as f :
        instruction = f.read()

    formated_terms = {"input" : text,
                    "output" : output_text, 
                    "instruction" : instruction}

    return formated_terms

parse_dataset_into_json(0, "top3")
# Out:
# {'input': ' \nName:  ___                    Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nBactrim\n \nAttending: ___.\n \nChief Complaint:\nbilateral lower extremity edema\n \nMajor Surgical or Invasive Procedure:\nRight heart catheterization ___\n\n \nHistory of Present Illness:\nMr. ___ is a ___ ___ male with history of\nchronic respiratory failure on home 4L O2 with restrictive lung\ndisease ___ kyphoscoliosis from Potts disease, HFpEF, OSA on \nhome\nPAP, presumed pulmonary hypertension without prior RHC, T2DM,\nHTN, HLD who presents with ___. \n\nThe patient reports he has had swelling in both feet for the \npast\nweek, and that he increased his torsemide dose from 60mg to 80mg\ndaily, without any improvement in the edema. ED report of DOE\nwith walking, but patient is consistent now in stating that  he\nnever had any SOB or DOE and that he only had difficulty walking\nbecause his feet were so swollen. No CP or orthopnea. \n\nHis baseline weight is 180 lbs (which correlates to 183 lbs in\nhis outpatient clinic weights due to difference in scales). he\nreports having gained 2.9 lbs over the past week, with weight\nprior to presentation of 182.9. Denies dietary indiscretions, \nson\ncooks and keeps a low salt diet. Denies medication \nnoncompliance.\nNo recent infectious symptoms including f/c, cough, sputum, N/V,\nabd pain, diarrhea, dysuria. \n \nIn the ED initial vitals were:  \nT 98.0  HR 79  BP 134/62  RR 18  O2 Sat 100% RA \n \nEKG: Sinus 71 with left axis, normal intervals, no ST elevation\nor depression, no ischemic T-wave changes, compared to prior \nfrom\n___. \n \nED exam was notable for:\n2+ pitting edema bilateral feet extending to upper ankle\nBibasilar crackles\nHe is on his home O2\n\nLabs/studies notable for:  \nproBNP: 109, trop neg x1\nCr 1.5\n\nCXR: moderate pulmonary edema with moderate cardiomegaly and\npotential small bilateral pleural effusions. Mild retrocardiac\natelectasis. No evidence of pneumonia. No pneumothorax. \n \nPatient was given:  IV Furosemide 40 mg \nHe was placed on his home O2 4LNC and is saturating at 97% on 4L\n \nVitals on transfer:   64, 117/61, 18, 97% 4L NC \n\nOn the floor, patient reports history as described above. \nFeeling\nwell. No SOB. Feels like his ___ is actually improving since\npresentation. Reports he did seem to urinate a lot to the Lasix\nin the ED.  Son at bedside, helping to translate. \n \nREVIEW OF SYSTEMS:  \n10 point ROS negative except as in HPI above.  \n\n \nPast Medical History:\n1. CARDIAC RISK FACTORS  \n- Diabetes - A1c 6.5 in ___ not on meds\n- HTN \n- HLD \n- obesity \n- prior tobacco use\n\n2. CARDIAC HISTORY  \n- CHF with preserved EF \n\n3. OTHER PAST MEDICAL HISTORY  \n- H/o chronic respiratory failure  on 4 liters at home\n- Restrictive lung disease\n- OSA on BIPAP\n- Hypoventilation; hypercapnia\n- pulmonary hypertension\n- Decreased hearing due to cholesteatoma\n- diverticulosis \n- gastritis \n- gout \n- kyphoscoliosis ___ Potts disease      \n \nSocial History:\n___\nFamily History:\nFather died at age ___ of unclear etiology.  Mother died of \nasthma\nat age ___.  He has four brothers and sisters who are healthy. \nThere is no family history of stroke, hyperlipidemia,\nhypertension, early coronary artery disease or sudden cardiac\ndeath.\n \nPhysical Exam:\nADMISSION PHYSICAL EXAMINATION:  \n===============================\nVS: 98.4PO, 157 / 75, 67, 20, 99 4L \nGENERAL: Well developed, well nourished man in NAD. Oriented x3.\nMood, affect appropriate. Significant kyphosis. \nHEENT: Normocephalic atraumatic. Sclera anicteric. EOMI.\nConjunctiva were pink.   \nNECK: Supple. JVP to ear at 45 degrees. \nCARDIAC: Regular rate and rhythm. Normal S1, S2. No murmurs,\nrubs, or gallops. \nLUNGS: Respiration is unlabored with no accessory muscle use on\nhome 4L O2. Fine bl crackles, no wheezing. \nABDOMEN: Soft, non-tender, non-distended ...
#  'output': '1. bilateral lower extremity edema\n2. chronic respiratory failure\n2.1 home o2\n3. restrictive lung disease\n3.1 budesonide\n',
#  'instruction': "\nYou are a helpful assistant, an expert in medical domain. \nExtract top 3 main diagnosis/symptoms or conditions mentioned in the medical note. \nFollowing the diagnosis/symptoms or conditions, identify the medical tests related to it.\nIf there isn't any medical tests related to it, just start listing the next important diagnosis/symptoms or conditions.\nIf there are no additional diagnosis/symptoms or conditions that you can identify, just list the existing ones and finalize the output. \nDon't write no symptoms, or any indication that there is no other diagnosis/symptoms or conditions.\nDo not modify or abbreviate what is written in the notes. Just extract them as they are.\nMake sure the highest priority is assigned with a smaller number.\nWe give you an example, do follow as below.\nThe format should be as follows\n\n1. key symptom or condition\n1.1 medical test related to 1\n1.2 medical test related to 1\n2. key symptom or condition\n2.1 medical test related to 2\n3. key symptom or condition\n3.1 medical test related to 3\n3.2 medical test related to 3"}

# %%
import random
import numpy as np

np.random.seed(0)
random.seed(0)

parsed_dataset = []
topns = ["top3", "top5", "top10"]

for idx in range(len(synthetic_data)) : 
    topn= np.random.choice(topns)
    output = parse_dataset_into_json(idx, topn)
    parsed_dataset.append(output)

# %%
# random.seed(0)

random.Random(0).shuffle(parsed_dataset)
parsed_dataset[0]
# Out:
# {'input': ' \nName:  ___               Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___\n \nChief Complaint:\nL-sided flank pain and cough\n \nMajor Surgical or Invasive Procedure:\nNone\n\n \nHistory of Present Illness:\n___ with DM, HTN, TIA, tobacco abuse, obesity, and asthma who \npresented to clinic with cough and atypical chest pain. He had a \nURI three weeks ago and recovered but has residual persistent \ncough x 3 weeks productive of yellow sputum. He also has had \nL-sided chest pain x 1 week, described as dull, throbbing \npersistent pain, not pleuritic and not associated with exertion \nor positional change. It does not radiate and he has had no SOB, \nnausea, lightheadedness. Patient was seen in clinic today with \nEKG which showed new TWI in I, II, aVL, V3, prompting transfer \nto ED. He takes full dose aspirin daily for history of TIA. In \nthe ED, initial VS: 98.4 193/92 77 20 98% RA. Exam notable for \nexpiratory wheezes. Troponins negative. Given duonebs. Admitted \nfor r/o ACS. \n \nPast Medical History:\nHTN\nHyperlipidemia\nHistory of DM, now diet controlled and off medications\nGout\nProstate cancer s/p resection\n \nSocial History:\n___\nFamily History:\nMother died in ___ of MI. No strokes or seizures in family.\n \nPhysical Exam:\nADMISSION\nVS: 98.3 166/83 66 19 97% RA  \nGENERAL: WDWN man in NAD. Oriented x3. Mood, affect appropriate. \n \nHEENT: NCAT. Sclera anicteric. PERRL, EOMI. Conjunctiva were \npink, no pallor or cyanosis of the oral mucosa. No xanthelasma.  \n\nNECK: Supple with JVP difficult to assess secondary to body \nhabitus.  \nCARDIAC: PMI located in ___ intercostal space, midclavicular \nline. RR, normal S1, S2. No m/r/g. No thrills, lifts. No S3 or \nS4. TTP over left chest wall.  \nLUNGS: No chest wall deformities, scoliosis or kyphosis. Resp \nwere unlabored, no accessory muscle use. CTAB, no crackles, \nwheezes or rhonchi.  \nABDOMEN: Soft, NTND. No HSM or tenderness.  \nEXTREMITIES: No c/c/e.  \nSKIN: No stasis dermatitis, ulcers, scars, or xanthomas. \n\nDISCHARGE\nVS: 97.9, 166-72/83-97, 66-74, ___ RA\nI/O: 360/250 // NR\nWt 114 kg\nGENERAL: WDWN man in NAD. Oriented x3. Mood, affect appropriate. \n \nHEENT: NCAT. Sclera anicteric. PERRL, EOMI. Conjunctiva were \npink, no pallor or cyanosis of the oral mucosa. No xanthelasma.  \n\nNECK: Supple with JVP difficult to assess secondary to body \nhabitus.  \nCARDIAC: PMI located in ___ intercostal space, midclavicular \nline. RR, normal S1, S2. No m/r/g. No thrills, lifts. No S3 or \nS4. TTP over left chest wall.  \nLUNGS: No chest wall deformities, scoliosis or kyphosis. Resp \nwere unlabored, no accessory muscle use. CTAB, no crackles, \nwheezes or rhonchi.  \nABDOMEN: Soft, NTND. No HSM or tenderness.  \nEXTREMITIES: No c/c/e.  \nSKIN: No stasis dermatitis, ulcers, scars, or xanthomas.\n \nPertinent Results:\n___ 09:10PM BLOOD WBC-6.5 RBC-4.54* Hgb-14.5 Hct-43.4 \nMCV-96 MCH-31.9 MCHC-33.4 RDW-13.7 Plt ___\n___ 09:10PM BLOOD Neuts-60.7 ___ Monos-5.9 Eos-1.7 \nBaso-0.2\n___ 09:32PM BLOOD ___ PTT-28.4 ___\n___ 09:10PM BLOOD Plt ___\n___ 03:26AM BLOOD Glucose-216* UreaN-24* Creat-1.2 Na-136 \nK-4.1 Cl-101 HCO3-22 AnGap-17\n___ 09:10PM BLOOD Glucose-108* UreaN-24* Creat-1.1 Na-138 \nK-4.3 Cl-105 HCO3-18* AnGap-19\n___ 03:26AM BLOOD CK(CPK)-325*\n___ 09:20AM BLOOD cTropnT-PND\n___ 03:26AM BLOOD CK-MB-4 cTropnT-<0.01\n___ 09:10PM BLOOD cTropnT-<0.01\n___ 09:10PM BLOOD proBNP-89\n___ 03:26AM BLOOD Calcium-9.1 Phos-3.1 Mg-2.0\n\nExercise stress test ___\nINTERPRETATION: ___ yo man with HTN, HL and DM was referred to \nevaluate an atypical chest discomfort and baseline ECG \nabnormalities. \nThe patient completed 10 minutes and 0 seconds of a Gervino \nprotocol \nrepresenting a poor exercise tolerance for his age; ~ ___ METS, \nhowever \nsimilar exercise tolerance to E ...
#  'output': '1. atypical chest pain\n1.1 stress test\n2. persistent cough\n2.1 cxr\n3. t2dm\n3.1 hiss\n',
#  'instruction': "\nYou are a helpful assistant, an expert in medical domain. \nExtract top 3 main diagnosis/symptoms or conditions mentioned in the medical note. \nFollowing the diagnosis/symptoms or conditions, identify the medical tests related to it.\nIf there isn't any medical tests related to it, just start listing the next important diagnosis/symptoms or conditions.\nIf there are no additional diagnosis/symptoms or conditions that you can identify, just list the existing ones and finalize the output. \nDon't write no symptoms, or any indication that there is no other diagnosis/symptoms or conditions.\nDo not modify or abbreviate what is written in the notes. Just extract them as they are.\nMake sure the highest priority is assigned with a smaller number.\nWe give you an example, do follow as below.\nThe format should be as follows\n\n1. key symptom or condition\n1.1 medical test related to 1\n1.2 medical test related to 1\n2. key symptom or condition\n2.1 medical test related to 2\n3. key symptom or condition\n3.1 medical test related to 3\n3.2 medical test related to 3"}

# %%
idx = int(len(parsed_dataset)*0.2)
testset, trainset = parsed_dataset[:idx], parsed_dataset[idx:]

# %%
len(testset), len(trainset)
# Out:
# (200, 800)

# %%
with open(DATA_PATH.joinpath("discharge_dataset.json"), "w") as f : 
    json.dump(parsed_dataset, f)

with open(DATA_PATH.joinpath("discharge_dataset_train.json"), "w") as f : 
    json.dump(trainset, f)

with open(DATA_PATH.joinpath("discharge_dataset_test.json"), "w") as f : 
    json.dump(testset, f)
